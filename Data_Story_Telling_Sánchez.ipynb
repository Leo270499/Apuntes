# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo270499/Apuntes/blob/main/Data_Story_Telling_S%C3%A1nchez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Churn:** Desentrañando el Desempleo Voluntario - *Un Análisis de las Tasas de Desempleo y el Abandono Laboral en la Economía*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Librerias
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = "/content/drive/MyDrive/Coderhouse_ Data Science/6. Primera Entrega (Data Science)/Dataset/Abandono.csv"
df = pd.read_csv(PATH, sep = ';', index_col= 'id', na_values='#N/D')

# %%
pd.set_option('display.max_columns', 31)

# %%
df.sample(5)
# Out:
#       edad abandono             viajes            departamento  \
# id
# 766     29       No      Travel_Rarely                   Sales
# 1306    45       No  Travel_Frequently  Research & Development
# 244     46       No      Travel_Rarely                   Sales
# 2053    29       No      Travel_Rarely  Research & Development
# 47      50      Yes      Travel_Rarely                   Sales
#
#       distancia_casa      educacion    carrera  empleados  \
# id
# 766               10            NaN  Marketing          1
# 1306              25  Universitaria    Medical          1
# 244                1  Universitaria  Marketing          1
# 2053              13     Secundaria      Other          1
# 47                 3     Secundaria  Marketing          1
#
#      satisfaccion_entorno  sexo implicacion  nivel_laboral  \
# id
# 766              Muy_Alta   3.0        Alta              1
# 1306                Media   3.0        Alta              5
# ...
